# %%
import pandas as pd
import json
from prettytable import PrettyTable

# %% [markdown]
# # Get the data

# %%
#load the file
with open("data.json", "r") as f:
    data = json.load(f)

#get the stats part
stats_data = data["stats"]

#convert to df
df = pd.json_normalize(stats_data)
df
# Out:
#      year  playerId          playerName    type  rank      playerFullName  \
# 0    2024    596133         Luke Weaver  player     1         Luke Weaver
# 1    2024    668674         Lucas Erceg  player     2         Lucas Erceg
# 2    2024    595014       Blake Treinen  player     2       Blake Treinen
# 3    2024    689225        Beau Brieske  player     4        Beau Brieske
# 4    2024    661403      Emmanuel Clase  player     4      Emmanuel Clase
# ..    ...       ...                 ...     ...   ...                 ...
# 134  2024    554430        Zack Wheeler  player    15        Zack Wheeler
# 135  2024    668909      Gavin Williams  player    15      Gavin Williams
# 136  2024    808967  Yoshinobu Yamamoto  player    15  Yoshinobu Yamamoto
# 137  2024    664849         Danny Young  player    15         Danny Young
# 138  2024    672582         Angel Zerpa  player    15         Angel Zerpa
#
#     playerFirstName playerLastName playerUseName playerInitLastName  ...  \
# 0              Luke         Weaver          Luke           L Weaver  ...
# 1             Lucas          Erceg         Lucas            L Erceg  ...
# 2             Blake        Treinen         Blake          B Treinen  ...
# 3              Beau        Brieske          Beau          B Brieske  ...
# 4          Emmanuel          Clase      Emmanuel            E Clase  ...
# ..              ...            ...           ...                ...  ...
# 134         Zachary        Wheeler          Zack          Z Wheeler  ...
# 135           Gavin       Williams         Gavin         G Williams  ...
# 136       Yoshinobu       Yamamoto     Yoshinobu         Y Yamamoto  ...
# 137          Daniel          Young         Danny            D Young  ...
# 138           Angel          Zerpa         Angel            A Zerpa  ...
#
#      totalBases groundOutsToAirouts winPercentage strikeoutWalkRatio  \
# 0            15                0.56         1.000               8.00
# 1             8                2.67          .---               2.00
# 2            13                1.38         1.000               4.50
# 3             4                0.38          .000               3.00
# 4            22                1.43          .000               8.00
# ..          ...                 ...           ...                ...
# 134           1                0.83          .---               2.25
# 135           9                2.00          .---               -.--
# 136          23                1.50         1.000               2.50
# 137           5                3.00          .---               1.00
# 138           2                2.00         1.000               1.67
#
#     strikeoutsPer9Inn  walksPer9Inn hitsPer9Inn catchersInterference sacBunts  \
# 0                9.39          1.17        4.70                    1        0
# 1                9.00          4.50        6.00                    0        0
# 2               13.14          2.92        8.76                    0        0
# 3                9.00          3.00        1.50                    0        0
# 4                9.00          1.13       13.50                    0        0
# ..                ...           ...         ...                  ...      ...
# 134             11.57          5.14        1.29                    0        0
# 135             15.43          0.00       11.57                    0        0
# 136              7.23          2.89        5.79                    0        0
# 137              7.36          7.36        9.82                    0        0
# 138             11.25          6.75        4.50                    0        0
#
#      sacFlies
# 0           3
# 1           0
# 2           0
# 3           0
# 4           0
# ..        ...
# 134         0
# 135         0
# 136         0
# 137         0
# 138         0
#
# [139 rows x 115 columns]

# %% [markdown]
# # Clean the df

# %%
print(df.columns.tolist())
# get rid of def useless columns

# get rid of not useful right now columns
# Out:
# ['year', 'playerId', 'playerName', 'type', 'rank', 'playerFullName', 'playerFirstName', 'playerLastName', 'playerUseName', 'playerInitLastName', 'teamId', 'teamAbbrev', 'teamName', 'teamShortName', 'leagueName', 'leagueId', 'positionAbbrev', 'position', 'primaryPositionAbbrev', 'age', 'winningPercentage', 'runsScoredPer9', 'battersFaced', 'babip', 'obp', 'slg', 'ops', 'strikeoutsPer9', 'baseOnBallsPer9', 'homeRunsPer9', 'hitsPer9', 'strikesoutsToWalks', 'inheritedRunners', 'inheritedRunnersScored', 'bequeathedRunners', 'bequeathedRunnersScored', 'stolenBases', 'caughtStealing', 'qualityStarts', 'gamesFinished', 'doubles', 'triples', 'gidp', 'gidpOpp', 'wildPitches', 'balks', 'pickoffs', 'totalSwings', 'swingAndMisses', 'strikeoutsMinusWalksPercentage', 'gidpPercentage', 'battersFacedPerGame', 'buntsFailed', 'buntsMissedTipped', 'whiffPercentage', 'ballsInPlay', 'runSupport', 'strikePercentage', 'pitchesPerInning', 'pitchesPerPlateAppearance', 'walksPerPlateAppearance', 'strikeoutsPerPlateAppearance', 'homeRunsPerPlateAppearance', 'walksPerStrikeout', 'iso', 'flyOuts', 'popOuts', 'lineOuts', 'groundOuts', 'flyHits', 'popHits', 'lineHits', 'groundHits', 'gamesPlayed', 'gamesStarted', 'airOuts', 'runs', 'homeRuns', 'strikeOuts', 'baseOnBalls', 'intentionalWalks', 'hits', 'hitByPitch', 'avg', 'atBats', 'stolenBasePercentage', 'caughtStealingPercentage', 'groundIntoDoublePlay', 'numberOfPitches', 'era', 'inningsPitched', 'wins', 'losses', 'saves', 'saveOpportunities', 'holds', 'blownSaves', 'earnedRuns', 'whip', 'outs', 'gamesPitched', 'completeGames', 'shutouts', 'strikes', 'hitBatsmen', 'totalBases', 'groundOutsToAirouts', 'winPercentage', 'strikeoutWalkRatio', 'strikeoutsPer9Inn', 'walksPer9Inn', 'hitsPer9Inn', 'catchersInterference', 'sacBunts', 'sacFlies']
